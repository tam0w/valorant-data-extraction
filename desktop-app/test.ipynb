# %%
import cv2 as cv, easyocr, matplotlib.pyplot as plt

# %%
file = cv.imread(r'D:\PROJECTS\demo-analysis-timeline\res\scoreboard.png')

# %%
file = cv.imread(r'D:\PROJECTS\demo-analysis-timeline\res\frame.png')
file = file[500:860,900:1600]

# %%
reader = easyocr.Reader(['en'])
res = reader.readtext(file)
print(res)
for (bbox, text, prob) in res:

  (tl, tr, br, bl) = bbox
  tl = (int(tl[0]), int(tl[1]))
  tr = (int(tr[0]), int(tr[1]))
  br = (int(br[0]), int(br[1]))
  bl = (int(bl[0]), int(bl[1]))
  cv.rectangle(file, tl, br, (0, 255, 0), 2)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[93, 13], [129, 13], [129, 29], [93, 29]], '0:19', 0.5444096635733144), ([[299, 13], [325, 13], [325, 29], [299, 29]], '3m', 0.9989864345121692), ([[93, 51], [129, 51], [129, 67], [93, 67]], '0:22', 0.594849517700809), ([[269, 51], [325, 51], [325, 67], [269, 67]], 'Planted', 0.9999913490676681), ([[93, 89], [129, 89], [129, 105], [93, 105]], '0:37', 0.7284666895866394), ([[289, 89], [325, 89], [325, 105], [289, 105]], '24m', 0.9992954664579035), ([[93, 127], [129, 127], [129, 143], [93, 143]], '0:37', 0.7025220394134521), ([[289, 127], [323, 127], [323, 145], [289, 145]], '21m', 0.6968032121658325), ([[93, 165], [129, 165], [129, 181], [93, 181]], '0:39', 0.7232763171195984), ([[291, 165], [323, 165], [323, 181], [291, 181]], '14m', 0.9913086289176608), ([[93, 203], [129, 203], [129, 219], [93, 219]], '0:40', 0.6408552527427673), ([[297, 203], [323, 203], [323, 219], [297, 219]], '9m', 0.9948826642294588), ([[93, 241], [129, 241], [129, 257], [93, 257]], '0.43', 0.763049840927124), ([[299, 241], [325, 241], [325, 257], [299, 257]], '6m', 0.8112844148248866), ([[93, 279], [129, 279], [129, 295], [93, 295]], '0:51', 0.7873882547329601), ([[297, 279], [325, 279], [325, 295], [297, 295]], 'Tm', 0.7855463714035057), ([[93, 317], [129, 317], [129, 333], [93, 333]], '0:54', 0.6448700308597438), ([[289, 317], [325, 317], [325, 333], [289, 333]], '12m', 0.9998181652032945)]

# %%
plt.figure(figsize=(10,15))
plt.imshow(file)

# %%
for (bbox, text, prob) in res:
  print(text)
# Out:
# 0:19
# 3m
# 0:22
# Planted
# 0:37
# 24m
# 0:37
# 21m
# 0:39
# 14m
# 0:40
# 9m
# 0.43
# 6m
# 0:51
# Tm
# 0:54
# 12m

# %%
import cv2 as cv, easyocr, tkinter, numpy as np, matplotlib.pyplot as plt

reader = easyocr.Reader(['en'])

# def preprocessing(img):
#     """ Perfrom all the image preprocessing here. Not sure how to handle different images needing different preprocessing
#     but lets see."""
#     return finalimg
#
# def run_ocr(img):
#     result = reader.readtext(img, detail=0)
#     return result


ogfile = cv.imread('../res/frame.png')
# cv.imshow('test',file[50:200,50:200])
file = ogfile[50:200,50:200]
gray = cv.cvtColor(file, cv.COLOR_BGR2GRAY)
plt.imshow(gray)
plt.show()
print(reader.readtext(gray,detail=0))



cv.waitKey(0)

# %%
# import tkinter as tk
# from tkinter import *
# from tkinter import Label, font
#
# win = tk.Tk()
# fonts=list(font.families())
# rowcount = 0
# columncount =0
#
# for i in fonts:
#     if rowcount % 30 == 0:
#         columncount+=1
#         rowcount = 0
#     Label(win,text = i, font =(i,10,'bold')).grid(row=rowcount, column=columncount)
#     rowcount+=1
#
# win.mainloop()

# %%
# /# file = cv.bitwise_not(file)
# file = cv.cvtColor(file, cv.COLOR_BGR2GRAY)
# ret, file = cv.threshold(file, 150,30, 0)
# plt.figure(figsize=(10,15))
# plt.imshow(file)
