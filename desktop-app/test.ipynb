# %%
import time
import pyautogui
import cv2 as cv, easyocr, matplotlib.pyplot as plt, pandas as pd, os, numpy as np

# %%
# time.sleep(2)
# # image = pyautogui.screenshot()
cv_image = cv.cvtColor(np.array(image), cv.COLOR_BGR2RGB)
val = cv_image[520,1150]
# val = cv_image[630,1150]
# plt.imshow(val)
# plt.figure(figsize=(10,25))
# plt.show()
val
# Out:
# array([ 89, 111, 109], dtype=uint8)

# %%
file = cv.imread(r'D:\PROJECTS\demo-analysis-timeline\res\chamber.png', cv.COLOR_RGB2BGR)
skye1 = file[504:544,164:204]

plt.imshow(skye1)
plt.show()


# for agent in agent_list:
#     agent = cv.resize(agent,(0, 0),fx=0.39, fy=0.39, interpolation = cv.INTER_AREA)
#     result = cv.matchTemplate(tl, agent, cv.TM_CCORR_NORMED)
#     min_val, max_val, min_loc, max_loc = cv.minMaxLoc(result)
#     values.append(max_val)




# values
# print(agent_list)
# agents = [cv.imread(agent,0) for agent in agent_list]

# %%
file = cv.imread(r'D:\PROJECTS\demo-analysis-timeline\res\skye.png', cv.COLOR_RGB2BGR)
skye2 = file[506:542, 945:980]
skye2 = cv.resize(skye2,dsize=(40,40))
plt.imshow(skye2)
plt.show()

# %%
temp = cv.matchTemplate(skye2, skye1, cv.TM_CCORR_NORMED)
min_val, max_val, min_loc, max_loc = cv.minMaxLoc(temp)
print(max_val)
# Out:
# 0.9303111433982849

# %%
plt.figure(figsize=(10,15))
plt.imshow(tl)

# %%
reader = easyocr.Reader(['en'])
res = reader.readtext(file)
print(res)
for (bbox, text, prob) in res:

  (tl, tr, br, bl) = bbox
  tl = (int(tl[0]), int(tl[1]))
  tr = (int(tr[0]), int(tr[1]))
  br = (int(br[0]), int(br[1]))
  bl = (int(bl[0]), int(bl[1]))
  cv.rectangle(file, tl, br, (0, 255, 0), 2)

# %%
file = cv.imread(r'D:\PROJECTS\demo-analysis-timeline\res\skye.png', 0)
tl = file[506:539,945:980]

values = []
sprite_path = r'D:\PROJECTS\demo-analysis-timeline\res\sprites'
dir_list = os.listdir(sprite_path)
print(dir_list)
sprite_list = []
for i,file in enumerate(dir_list):
  file = os.path.join(sprite_path,file)
  img = cv.imread(file,0)
  sprite_list.append(img)

for agent in sprite_list:
    agent = cv.resize(agent,dsize=(40,40))
    result = cv.matchTemplate(tl, agent, cv.TM_CCOEFF_NORMED)
    min_val, max_val, min_loc, max_loc = cv.minMaxLoc(result)
    values.append(max_val)
    plt.imshow(agent)
    plt.show()

print(values)
print(values.index(max(values)),"HI",max(values))
print(dir_list)
plt.imshow(tl)
# agents = [cv.imread(agent,0) for agent in agent_list]
# Out:
# ['astra.png', 'breach_bg.png', 'brim.png', 'chamber.png', 'cypher.png', 'deadlock.png', 'fade.png', 'ge.png', 'harbour.png', 'jett.png', 'kayo.png', 'kj.png', 'neon.png', 'omen.png', 'phx_bg.png', 'raze.png', 'reyna.png', 'sage.png', 'skye.png', 'sova.png', 'viper_bg.png', 'yoru.png']
# [0.2571832537651062, 0.190291628241539, 0.19118723273277283, 0.004566232208162546, 0.03212762996554375, 0.051059234887361526, 0.3250782787799835, 0.12980511784553528, 0.2859821319580078, 0.13780193030834198, 0.3330966830253601, -0.05716937780380249, 0.3420395255088806, 0.07111915946006775, 0.18978552520275116, 0.146389901638031, 0.33109259605407715, 0.4661499559879303, 0.42023658752441406, 0.15749217569828033, 0.21689632534980774, 0.31030580401420593]
# 17 HI 0.4661499559879303
# ['astra.png', 'breach_bg.png', 'brim.png', 'chamber.png', 'cypher.png', 'deadlock.png', 'fade.png', 'ge.png', 'harbour.png', 'jett.png', 'kayo.png', 'kj.png', 'neon.png', 'omen.png', 'phx_bg.png', 'raze.png', 'reyna.png', 'sage.png', 'skye.png', 'sova.png', 'viper_bg.png', 'yoru.png']

# %%
# agents.sort_values(by='names',axis=0,inplace=True)
# agents.reset_index(inplace=True,drop=True)
# agents
# agents.to_csv(r'D:\PROJECTS\demo-analysis-timeline\res\agentinfo.csv')

# %%
# import tkinter as tk
# from tkinter import *
# from tkinter import Label, font
#
# win = tk.Tk()
# fonts=list(font.families())
# rowcount = 0
# columncount =0
#
# for i in fonts:
#     if rowcount % 30 == 0:
#         columncount+=1
#         rowcount = 0
#     Label(win,text = i, font =(i,10,'bold')).grid(row=rowcount, column=columncount)
#     rowcount+=1
#
# win.mainloop()

# %%
import cv2 as cv, easyocr, tkinter, numpy as np, matplotlib.pyplot as plt

reader = easyocr.Reader(['en'])

ogfile = cv.imread('../res/firstpage.png')
cv_image = cv.cvtColor(np.array(image), cv.COLOR_RGB2BGR)
file = cv_image[495:940, 150:370]
gray = cv.cvtColor(file, cv.COLOR_RGB2BGR)
result = reader.readtext(gray, detail=0)

player_names = [name for name in result if (result.index(name) % 2) == 0]
agent_names = [name for name in result if (result.index(name) % 2) == 1]

player_agents_zipped = dict(zip(agent_names, player_names))

player_agents_zipped
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# {'Reyna': 'Onuphrius',
#  'Sova': 'Kuno',
#  'Chamber': 'HITMAN',
#  'Jett': 'TheWeeknd',
#  'Omen': 'PaiN',
#  'Raze': 'Xan',
#  'Brimstone': 'PunlsheR',
#  'Cypher': 'priyansh'}

# %%
image = cv.imread('../res/first.png')
cv_image = cv.cvtColor(np.array(image), cv.COLOR_RGB2BGR)
file = cv_image[495:940, 150:370]
gray = cv.cvtColor(file, cv.COLOR_RGB2BGR)

# res1 = reader.readtext(gray, detail=0)
# result = res1[0].__str__().lower()
#     
# if result.__contains__('def'):
#     first = "Defense"
#     second = "Attack"
# else:
#     second = "Defense"
#     first = "Attack"
#         
# print([first] * 12 + [second] * 12)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 6
#       4 gray = cv.cvtColor(file, cv.COLOR_RGB2BGR)
#       5 plt.imshow(gray)
# ----> 6 plt.show(gray)
#       7 # res1 = reader.readtext(gray, detail=0)
#       8 # result = res1[0].__str__().lower()
#       9 #
#    (...)
#      16 #
#      17 # print([first] * 12 + [second] * 12)
#
# File D:\PROJECTS\demo-analysis-timeline\venv\Lib\site-packages\matplotlib\pyplot.py:446, in show(*args, **kwargs)
#     402 """
#     403 Display all open figures.
#     404
#    (...)
#     443 explicitly there.
#     444 """
#     445 _warn_if_gui_out_of_main_thread()
# --> 446 return _get_backend_mod().show(*args, **kwargs)
#
# File D:\PROJECTS\demo-analysis-timeline\venv\Lib\site-packages\matplotlib_inline\backend_inline.py:98, in show(close, block)
#      95 show._to_draw = []
#      96 # only call close('all') if any to close
#      97 # close triggers gc.collect, which can be slow
# ---> 98 if close and Gcf.get_all_fig_managers():
#      99     matplotlib.pyplot.close('all')
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
zipped = [("test",'welp'),('nope','TEST')]

print(zipped.__contains__('(\"test\",\'welp\')'))
# Out:
# False

# %%
list1 = [1,2,3,4,5]
list2 = [6,7,8,9,10]

listed = zip(list1,list2)
dict(listed)
# Out:
# {1: 6, 2: 7, 3: 8, 4: 9, 5: 10}

# %%
list_of_paths = [ r'D:\PROJECTS\demo-analysis-timeline\res\cropped.png' , r'D:\PROJECTS\demo-analysis-timeline\res\chamber.png',r'D:\PROJECTS\demo-analysis-timeline\res\first.png']
tl_ss = []

for path in list_of_paths:
    image = cv.imread(path)
    tl_ss.append(image)
    # b, g, r = image[520, 1150]
    # print(g)
# Out:
# [60 49 97]

# %%
l1 =['LiveMht', 'ValkoN', 'RIP', 'hunter', 'LegendarySanin', 'maheshDALLE', 'Syther', 'Bankai', 'Portgas D Ace', 'Bakchod Bablu'] 
l2 = ['Neon', 'Phoenix', 'Jett', 'Deadlock', 'Reyna', 'Reyna', 'Chamber', 'Omen', 'Jett', 'Killjoy']
print(dict(zip(l1,l2)))
# Out:
# {'LiveMht': 'Neon', 'ValkoN': 'Phoenix', 'RIP': 'Jett', 'hunter': 'Deadlock', 'LegendarySanin': 'Reyna', 'maheshDALLE': 'Reyna', 'Syther': 'Chamber', 'Bankai': 'Omen', 'Portgas D Ace': 'Jett', 'Bakchod Bablu': 'Killjoy'}
